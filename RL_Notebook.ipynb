# %% [markdown]
# ## **Installation Instructions**
#
# - https://github.com/jpmorganchase/abides-jpmc-public#installation

# %%
# !ls
# Out:
# drive  sample_data

# %%
cd /content/drive/MyDrive/RL Project/RL
# Out:
# /content/drive/.shortcut-targets-by-id/1o8NtCE35YcF2KKvQ-TgQrBGx9P5PGmt0/RL Project/RL

# %%
# !ls
# Out:
# classicalStrategy.py	  Figures	    requirements.txt.docx  tradingPerformance.py
# Data			  main.py	    runs		   tradingSimulator.py
# dataAugmentation.py	  __pycache__	    TDQN.py		   working_rl_env
# dataDownloader.py	  README.md	    timeSeriesAnalyser.py  yahoodata.py
# fictiveStockGenerator.py  requirements.txt  tradingEnv.py

# %%
# !pip install -r requirements.txt

# %%
# !ls
# Out:
# classicalStrategy.py	  Figures	    requirements.txt.docx  tradingPerformance.py
# Data			  main.py	    runs		   tradingSimulator.py
# dataAugmentation.py	  __pycache__	    TDQN.py		   working_rl_env
# dataDownloader.py	  README.md	    timeSeriesAnalyser.py  yahoodata.py
# fictiveStockGenerator.py  requirements.txt  tradingEnv.py

# %%
# !pip install tensorrt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-8.6.1.post1-py2.py3-none-any.whl size=17283 sha256=70b4d01f0bde1bdfd772acd64f76498f027f2487c0b87e7a9e4aac9d918d3f71
#   Stored in directory: /root/.cache/pip/wheels/f4/c8/0e/b79b08e45752491b9acfdbd69e8a609e8b2ed7640dda5a3e59
# Successfully built tensorrt
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
# !python main.py
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/compat/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   PANDAS_VERSION = LooseVersion(pd.__version__)
# 2023-12-17 17:15:48.625605: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 17:15:48.625654: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 17:15:48.626997: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #**Training**
#
# ![Image 12-15-23 at 5.02 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Results**

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/RL Project/RL/Figures/AAPLTrainingResults.png')

# %%
Image('/content/drive/MyDrive/RL Project/RL/Figures/AAPL_Rendering.png')

# %%
Image('/content/drive/MyDrive/RL Project/RL/Figures/AAPL_TrainingTestingPerformance.png')
